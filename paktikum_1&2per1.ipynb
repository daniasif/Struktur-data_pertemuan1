# %% [markdown]
# <a href="https://colab.research.google.com/github/daniasif/Struktur-data/blob/main/paktikum_1%262per1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 1 – Implementasi List

# %%
arr = []

# input 10 angka
for i in range(10):
    angka = int(input("Masukkan angka: "))
    arr.append(angka)

print("Array:", arr)
print("Nilai maksimum:", max(arr))
print("Nilai minimum:", min(arr))
print("Rata-rata:", sum(arr)/len(arr))
# Out:
# Masukkan angka: 1
# Masukkan angka: 22
# Masukkan angka: 12
# Masukkan angka: 22
# Masukkan angka: 3
# Masukkan angka: 1
# Masukkan angka: 4
# Masukkan angka: 5
# Masukkan angka: 44
# Masukkan angka: 66
# Array: [1, 22, 12, 22, 3, 1, 4, 5, 44, 66]
# Nilai maksimum: 66
# Nilai minimum: 1
# Rata-rata: 18.0

# %% [markdown]
# Praktikum 2 – Operasi Insert & Delete Manual

# %%
#buat grafik batang menggunakan matplotlib
import matplotlib.pyplot as plt
plt.bar(range(len(arr)), arr)
plt.title("Grafik Array")
plt.xlabel("Indeks")
plt.ylabel("Nilai")
plt.show()
